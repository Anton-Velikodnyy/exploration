# %%
import tensorflow as tf

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("~/MNIST")
# prepare sequence
X_train = mnist.train.images
X_test = mnist.test.images
Y_train = mnist.train.labels
Y_test = mnist.test.labels
# view a number
def gen_image(arr):
    size = int(np.sqrt(arr.shape[0]))
    two_d = (np.reshape(arr, (size, size)) * 255).astype(np.uint8)
    plt.imshow(two_d, interpolation='nearest')
    plt.show()
# Out:
# Extracting ~/MNIST/train-images-idx3-ubyte.gz
# Extracting ~/MNIST/train-labels-idx1-ubyte.gz
# Extracting ~/MNIST/t10k-images-idx3-ubyte.gz
# Extracting ~/MNIST/t10k-labels-idx1-ubyte.gz

# %%
# neat but not neccesary
def partition_image(images,partition=7):
    part_images = []
    for image in images:
        split = [np.hsplit(vs, partitions) for vs in np.vsplit(img_f, partitions)]
        flat_list = [item.flatten() for sublist in split for item in sublist]
        part_images.append(flat_list)
    return part_images

# %%
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.layers import LSTM
from tensorflow.python.keras.layers import GRU
from tensorflow.python.keras.applications.resnet50 import ResNet50
from tensorflow.python.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.python.keras.layers import TimeDistributed


# hyperparameters
n_neurons = 128
learning_rate = 0.001
batch_size = 128
n_epochs = 10

# parameters
n_steps = 28 # 28 rows
n_inputs = 28 # 28 cols
n_outputs = 10 # 10 classes

# define LSTM configuration
n_neurons = length
n_batch = length
n_epoch = 1000
# convolutional model
convo = ResNet50(weights=None)
# create LSTM
model = Sequential()
model.add(TimeDistributed(convo))
model.add(GRU(n_neurons))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
print(model.summary())
# train LSTM
model.fit(X, y, epochs=n_epoch, batch_size=n_batch, verbose=2)
# evaluate
result = model.predict(X, batch_size=n_batch, verbose=0)
for value in result:
	print('%.1f' % value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-198-3cda93d43c46> in <module>()
#      27 # create LSTM
#      28 model = Sequential()
# ---> 29 model.add(TimeDistributed(convo))
#      30 model.add(GRU(n_neurons))
#      31 model.add(Dense(1))
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/models.py in add(self, layer)
#     480           # know about its input shape. Otherwise, that's an error.
#     481           if not hasattr(layer, '_batch_input_shape'):
# --> 482             raise ValueError('The first layer in a '
#     483                              'Sequential model must '
#     484                              'get an `input_shape` argument.')
#
# ValueError: The first layer in a Sequential model must get an `input_shape` argument.

# %%
from numpy import array
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.layers import GRU
from tensorflow.python.keras.layers import TimeDistributed
# prepare sequence
# define LSTM configuration
n_neurons = length
n_batch = 1
n_epoch = 1000
# create LSTM
model = Sequential()
model.add(GRU(n_neurons, input_shape=(length, 1), return_sequences=True))
model.add(TimeDistributed(Dense(1)))
model.compile(loss='mean_squared_error', optimizer='adam')
print(model.summary())
# train LSTM
model.fit(X, y, epochs=n_epoch, batch_size=n_batch, verbose=2)
# evaluate
result = model.predict(X, batch_size=n_batch, verbose=0)
for value in result[0,:,0]:
	print('%.1f' % value)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# gru_1 (GRU)                  (None, None, 5)           105
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, None, 1)           6
# ...
# Total params: 111
# Trainable params: 111
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
#  - 1s - loss: 0.3188
# Epoch 2/1000
#  - 0s - loss: 0.3144
# Epoch 3/1000
#  - 0s - loss: 0.3101
# Epoch 4/1000
#  - 0s - loss: 0.3058
# Epoch 5/1000
#  - 0s - loss: 0.3015
# Epoch 6/1000
#  - 0s - loss: 0.2973
# Epoch 7/1000
#  - 0s - loss: 0.2931
# Epoch 8/1000
#  - 0s - loss: 0.2889
# Epoch 9/1000
#  - 0s - loss: 0.2848
# Epoch 10/1000
#  - 0s - loss: 0.2808
# Epoch 11/1000
#  - 0s - loss: 0.2768
# Epoch 12/1000
#  - 0s - loss: 0.2728
# Epoch 13/1000
#  - 0s - loss: 0.2688
# Epoch 14/1000
# ...

# %%
# Get a batch of two random images and show in a pop-up window.
batch_xs, batch_ys = mnist.test.next_batch(2)
gen_image(batch_xs[0])
gen_image(batch_xs[1])
